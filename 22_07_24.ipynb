# %% [markdown]
# <a href="https://colab.research.google.com/github/Curry-codes/Python/blob/main/22_07_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a,b=30,39
if (a>b):
 print("T ")
else:
 print(bool(""))
# Out:
# False

# %%
# empty list
lis = []
print(lis,'is',bool(lis))
# empty tuple
t = ()
print(t,'is',bool(t))
# zero complex number
c = 0 + 0j
print(c,'is',bool(c))
num = 99
print(num, 'is', bool(num))
val = None
print(val,'is',bool(val))
val = True
print(val,'is',bool(val))
# empty string
str = ''
print(str,'is',bool(str))
str = 'Hello'
print(str,'is',bool(str))
# Out:
# [] is False
# () is False
# 0j is False
# 99 is True
# None is False
# True is True
#  is False
# Hello is True

# %%
def song():
 print("lyrics")
 song()
song()
# Out:
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# lyrics
# ...

# %%
def test():
 i=1
 while(i>=1):
  print(i)
  i=i+1
test()
# Out:
# Streaming output truncated to the last 5000 lines.
# 62060
# 62061
# 62062
# 62063
# 62064
# 62065
# 62066
# 62067
# 62068
# 62069
# 62070
# 62071
# 62072
# 62073
# 62074
# 62075
# 62076
# 62077
# 62078
# 62079
# 62080
# 62081
# 62082
# 62083
# 62084
# 62085
# 62086
# 62087
# 62088
# 62089
# 62090
# 62091
# 62092
# 62093
# 62094
# 62095
# 62096
# 62097
# 62098
# 62099
# 62100
# 62101
# 62102
# 62103
# 62104
# 62105
# 62106
# 62107
# 62108
# 62109
# 62110
# 62111
# 62112
# 62113
# 62114
# 62115
# 62116
# 62117
# 62118
# 62119
# 62120
# 62121
# 62122
# 62123
# 62124
# 62125
# 62126
# 62127
# 62128
# 62129
# 62130
# 62131
# 62132
# 62133
# 62134
# 62135
# 62136
# 62137
# 62138
# 62139
# 62140
# 62141
# 62142
# 62143
# 62144
# 62145
# 62146
# 62147
# 62148
# 62149
# 62150
# 62151
# 62152
# 62153
# 62154
# 62155
# 62156
# 62157
# 62158
# 62159
# 62160
# 62161
# 62162
# 62163
# 62164
# 62165
# 62166
# 62167
# 62168
# 62169
# 62170
# 62171
# 62172
# 62173
# 62174
# 62175
# 62176
# 62177
# ...

# %%
def test():
 i=0
 while(i<=1):
  print(i)
  i=i-1
test()
# Out:
# Streaming output truncated to the last 5000 lines.
# -1088380
# -1088381
# -1088382
# -1088383
# -1088384
# -1088385
# -1088386
# -1088387
# -1088388
# -1088389
# -1088390
# -1088391
# -1088392
# -1088393
# -1088394
# -1088395
# -1088396
# -1088397
# -1088398
# -1088399
# -1088400
# -1088401
# -1088402
# -1088403
# -1088404
# -1088405
# -1088406
# -1088407
# -1088408
# -1088409
# -1088410
# -1088411
# -1088412
# -1088413
# -1088414
# -1088415
# -1088416
# -1088417
# -1088418
# -1088419
# -1088420
# -1088421
# -1088422
# -1088423
# -1088424
# -1088425
# -1088426
# -1088427
# -1088428
# -1088429
# -1088430
# -1088431
# -1088432
# -1088433
# -1088434
# -1088435
# -1088436
# -1088437
# -1088438
# -1088439
# -1088440
# -1088441
# -1088442
# -1088443
# -1088444
# -1088445
# -1088446
# -1088447
# -1088448
# -1088449
# -1088450
# -1088451
# -1088452
# -1088453
# -1088454
# -1088455
# -1088456
# -1088457
# -1088458
# -1088459
# -1088460
# -1088461
# -1088462
# -1088463
# -1088464
# -1088465
# ...

# %%
def printstar():
  for i in l1:
    print("*"*i)
l1=[1,2,3,4]
printstar()
